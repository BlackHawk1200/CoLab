# %% [markdown]
# ##### Copyright 2024 Google LLC.

# %%
# Re-import necessary libraries to re-create the bar chart for Coventry City's home attendances

import matplotlib.pyplot as plt

# Data for Coventry City's home attendances (updated)
home_games = [
    {"opponent": "Oxford United", "attendance": 28051},
    {"opponent": "Oxford United (Cup)", "attendance": 11808},
    {"opponent": "Norwich City", "attendance": 27353},
    {"opponent": "Tottenham Hotspur", "attendance": 24616},
    {"opponent": "Swansea City", "attendance": 26273},
    {"opponent": "Blackburn Rovers", "attendance": 24583},
    {"opponent": "Sheffield Wednesday", "attendance": 28571},
    {"opponent": "Luton Town", "attendance": 26409},
    {"opponent": "Derby County", "attendance": 27243},
    {"opponent": "Sheffield United", "attendance": 28057},
    {"opponent": "Cardiff City", "attendance": 27137},
    {"opponent": "Hull City", "attendance": 25528}
]

# Extract data
games = [game["opponent"] for game in home_games]
attendances = [game["attendance"] for game in home_games]

# Plotting the chart
plt.figure(figsize=(10, 7))
bars = plt.barh(games, attendances, color='skyblue') #bars needed to be defined here
plt.xlabel('Attendance', fontsize=12)
plt.ylabel('Home Games', fontsize=12)
plt.title('Coventry City 2024-25 Home Game Attendances', fontsize=14)
plt.gca().invert_yaxis()  # Invert y-axis for easier reading
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Adding attendance text to each bar
for bar, attendance in zip(bars, attendances):
    plt.text(bar.get_width() + 170, bar.get_y() + bar.get_height() / 2,  # Position text to the right of each bar
             f"{attendance}",
             va='center',
             fontsize=7)


plt.tight_layout()



# Show the chart
plt.show()

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Gemini API Python quickstart

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://ai.google.dev/tutorials/quickstart_colab"><img src="https://ai.google.dev/static/site-assets/images/docs/notebook-site-button.png" height="32" width="32" />View on Google AI</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# This tutorial shows you how to get started with the Gemini API using the Python SDK.

# %% [markdown]
# ## Prerequisites
#
# You can run this tutorial in Google Colab, which doesn't require additional environment configuration.
#
# Alternatively, to complete this quickstart locally, see the Python guidance in [Get started with the Gemini API](https://ai.google.dev/tutorials/quickstart).

# %% [markdown]
# ## Install the SDK
#
# The Python SDK for the Gemini API is contained in the [`google-generativeai`](https://pypi.org/project/google-generativeai/) package. Install the dependency using pip:

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 1.1 MB/s eta 0:00:00

# %% [markdown]
# ## Set up your API key
#
# To use the Gemini API, you'll need an API key. If you don't already have one, create a key in Google AI Studio.
#
# <a class="button" href="https://aistudio.google.com/app/apikey" target="_blank" rel="noopener noreferrer">Get an API key</a>
#
# In Colab, add the key to the secrets manager under the "🔑" in the left panel. Give it the name `GOOGLE_API_KEY`. Then pass the key to the SDK:

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Initialize the Generative Model
#
# Before you can make any API calls, you need to initialize the Generative Model.

# %%
model = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ## Generate text

# %%
response = model.generate_content("Write a story about a magic backpack.")
print(response.text)
# Out:
# In the bustling city of Evermore, there lived an ordinary schoolgirl named Anya. Little did she know that her life was about to take an extraordinary turn when she discovered a peculiar backpack.
#
# One morning, as Anya rummaged through her grandmother's attic, her eyes fell upon a dusty old backpack. Intrigued, she picked it up and unzipped it. Inside, she found a jumble of papers, trinkets, and a small, glowing crystal.
#
# As Anya reached out to touch the crystal, the backpack hummed with a soft energy. Suddenly, strange things began to happen. The zippers moved on their own, opening and closing compartments that revealed hidden pockets. Book pages turned themselves, revealing forgotten spells and incantations.
#
# Anya realized that this was no ordinary backpack. It was a magical backpack, imbued with ancient enchantments. Excited and overwhelmed, she carefully put on the backpack and felt its power surge through her.
#
# ...

# %% [markdown]
# ## What's next
#
# To learn more about working with the Gemini API, see the [Python tutorial](https://ai.google.dev/tutorials/python_quickstart).
#
# If you're new to generative AI models, you might want to look at the
# [concepts guide](https://ai.google.dev/docs/concepts) and the
# [Gemini API overview](https://ai.google.dev/docs/gemini_api_overview).
